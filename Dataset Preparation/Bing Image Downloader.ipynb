# %%
# !pip install bing-image-downloader
# Out:
# /bin/bash: /home/portia/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...

# %%
from bing_image_downloader import downloader

# %%
downloader.download('Arn Curl Machine', limit=10000, output_dir='Alat Gym 3',
                    adult_filter_off=True)
# Out:
# [%] Downloading Images to /mnt/d/ThinkTank/Semester 5/Bangkit/Training/Alat Gym 3/Arn Curl Machine
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 96 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.technogym.com/en-INT/feed/images/MNRP/selection-900-arm-curl.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.panattagymequipment.com.au/wp-content/uploads/2020/05/pic-1mth056_04.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://images.jhtassets.com/27bf06b105c7885ce07005c426a9308c6fffeaca/
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.bodysolid.com/Images/Products/S2AC/600/S2AC_EX_M.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.intowellness.in/wp-content/uploads/2019/12/Seated-Bicep-Machine.jpg
# [%] File Downloaded !
#
# ...
